# %%
n=int(input("enter a number - "))
if n%2==0:
    if 2<= n <=5:
        print("Not Weird")
    elif 6 <= n <= 20:
        print("Weird")
    elif n>20:
        print("Not weird")
else:
    print("Weird")
# Out:
# Weird

# %%
import matplotlib.pyplot as plt

# Services and their respective fares
services = ["Uber", "Ola", "Rapido"]
fares = [3335, 3500, 2485]

# Plot the fare comparison
plt.figure(figsize=(8, 5))
plt.bar(services, fares, color=['blue', 'green', 'red'])

# Labels and Title
plt.xlabel("Ride Services")
plt.ylabel("Fare (₹)")
plt.title("Fare Comparison: Delhi to Jaipur")
plt.ylim(2000, 4000)

# Show values on top of bars
for i, fare in enumerate(fares):
    plt.text(i, fare + 50, f"₹{fare}", ha='center', fontsize=12, fontweight='bold')

# Show the plot
plt.show()
